# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
import skfuzzy
from sklearn.metrics import confusion_matrix

# %%
# Carregamento da base de dados iris, disponível no sklearn
iris = datasets.load_iris()

# %%
# Aplicação do algoritmo definindo três clusters (c = 3) e passando a matriz transposta (iris.data.T). Os outros parametros são obrigatórios e são os default indicados pela documentação
r = skfuzzy.cmeans(data = iris.data.T, c = 3, m = 2, error = 0.005,
                   maxiter = 1000, init = None)

# %%
# Obtendo em porcentagem de um registro pertencer a um cluster , que esta na posição 1 da matriz retornado
previsao_porcentagem = r[1]

# %%
# Visualizando em porcentagem de um registro pertencer a cada um dos cluster (o somatório é 1.0 que indica 100%)
for x in range(150):
  print(previsao_porcentagem[0][x], previsao_porcentagem[1][x], previsao_porcentagem[2][x])
# Out:
# 0.9966236290311652 0.0023044347138977423 0.001071936254937175
# 0.9758402776158971 0.01665871206577291 0.0075010103183298545
# 0.9798179323941825 0.013765509873056175 0.006416557732761444
# 0.9674111990361812 0.022477252125616173 0.0101115488382025
# 0.9944700638740931 0.003762040555180768 0.0017678955707261907
# 0.9345478751821649 0.0448254528596262 0.02062667195820891
# 0.979483366676574 0.014010034625795587 0.006506598697630384
# 0.9995470396200439 0.0003116985927985547 0.00014126178715749302
# 0.9303488479159263 0.04774113437700629 0.021910017707067308
# 0.9827137058292136 0.011942409066519787 0.005343885104266442
# 0.9680308704066323 0.021765216268446432 0.010203913324921262
# 0.9921325691798057 0.0054351851856205835 0.0024322456345738275
# 0.9706262407132 0.02019313952616421 0.009180619760635838
# 0.9229417979367727 0.05181502186459672 0.02524318019863049
# 0.8897287026691272 0.07263055376758167 0.037640743563291126
# 0.8413022833029965 0.10437816532699673 0.0543195513700069
# ...

# %%
# Gerando matriz de contingência para comparação com as classes originais da base de dados
previsoes = previsao_porcentagem.argmax(axis= 0)
resultados = confusion_matrix(iris.target, previsoes)
resultados
# Out:
# array([[50,  0,  0],
#        [ 0, 47,  3],
#        [ 0, 13, 37]], dtype=int64)
